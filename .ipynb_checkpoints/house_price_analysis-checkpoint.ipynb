# %% [markdown]
# # Анализ музыкальных данных
#
# ## Введение
# Целью данного проекта является анализ данных, содержащих информацию о музыкальных композициях. Задача - понять, какие факторы влияют на популярность песен, а также исследовать их жанры и акустические характеристики. Этот анализ поможет выявить ключевые характеристики, определяющие успех треков на музыкальных платформах.

# %%
import pandas as pd

# Загрузка данных
train_data = pd.read_csv('/mnt/data/train (1).csv')

# 1. Вывод первых 5 строк данных
train_data.head()

# 2. Статистическое описание данных
train_data.describe()

# 3. Проверка на пропущенные значения
train_data.isnull().sum()
